# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
projPath = '/content/drive/MyDrive/dsc_261/'
newsPath = os.path.join(projPath, 'datasets/News')
aaplPath = os.path.join(newsPath,'AAPL_News.csv')
PATH_PROJECT = '''/content/drive/MyDrive/dsc_261'''
PATH_DATA = os.path.join(PATH_PROJECT, 'datasets')

aggregated_folder = 'AGGREGATED_DATA'
PATH_AGG_DATA = os.path.join(PATH_DATA, aggregated_folder)

# %%
# %ls
# Out:
# AAPL.csv  BP.csv     D.csv     HSBC.csv          MDT.csv   PG.csv     T.csv    XOM.csv
# ABB.csv   BRK-A.csv  DHR.csv   IEP.csv           MMM.csv   PICO.csv   TM.csv   X_scaler.pkl
# ABBV.csv  BSAC.csv   DIS.csv   index_test.npy    MO.csv    PM.csv     TOT.csv  X_test.npy
# AEP.csv   BUD.csv    DUK.csv   index_train.npy   MRK.csv   PPL.csv    TSM.csv  X_train.npy
# AGFS.csv  CAT.csv    EXC.csv   INTC.csv          MSFT.csv  PTR.csv    UL.csv   yc_test.npy
# AMGN.csv  C.csv      FB.csv    JNJ.csv           NEE.csv   RDS-B.csv  UN.csv   yc_train.npy
# AMZN.csv  CELG.csv   GD.csv    JPM.csv           NGG.csv   REX.csv    UNH.csv  y_scaler.pkl
# BABA.csv  CHL.csv    GE.csv    KO.csv            NVS.csv   SLB.csv    UPS.csv  y_test.npy
# BAC.csv   CHTR.csv   GMRE.csv  LMT.csv           ORCL.csv  SNP.csv    UTX.csv  y_train.npy
# BA.csv    CMCSA.csv  GOOG.csv  LSTM_3to1.h5      PCG.csv   SNY.csv    V.csv
# BBL.csv   CODI.csv   HD.csv    lstm_diagram.png  PCLN.csv  SO.csv     VZ.csv
# BCH.csv   CSCO.csv   HON.csv   MA.csv            PEP.csv   SPLP.csv   WFC.csv
# BHP.csv   CVX.csv    HRG.csv   MCD.csv           PFE.csv   SRE.csv    WMT.csv

# %%
import pandas as pd

file_path = 'AAPL.csv'
df = pd.read_csv(file_path)

# %%
df.head(20)
# Out:
#           Date        Open        High        Low       Close  Adj Close  \
# 0   2012-09-04   95.108574   96.448570  94.928574   96.424286  87.121140
# 1   2012-09-05   96.510002   96.621429  95.657143   95.747147  86.509338
# 2   2012-09-06   96.167145   96.898575  95.828575   96.610001  87.288956
# 3   2012-09-07   96.864288   97.497147  96.538574   97.205711  87.827171
# 4   2012-09-10   97.207146   97.612854  94.585716   94.677139  85.542564
# 5   2012-09-11   95.015717   95.728569  93.785713   94.370003  85.265068
# 6   2012-09-12   95.264282   95.699997  93.714287   95.684288  86.452538
# 7   2012-09-13   96.767143   97.928574  96.395714   97.568573  88.155037
# 8   2012-09-14   98.565712   99.568573  98.269997   98.754288  89.226341
# 9   2012-09-17   99.907143   99.971428  99.230003   99.968575  90.323479
# 10  2012-09-18   99.982857  100.332855  99.488571  100.272858  90.598404
# 11  2012-09-19  100.037140  100.570000  99.938568  100.300003  90.622932
# 12  2012-09-20   99.879997  100.008568  99.088570   99.814285  90.184090
# 13  2012-09-21  100.344284  100.724289  99.908569  100.012856  90.363457
# 14  2012-09-24   98.122856   99.302856  97.571426   98.684288  89.163078
# 15  2012-09-25   98.322861   98.968575  96.142860   96.220001  86.936554
# 16  2012-09-26   95.534286   96.098572  94.457146   95.025711  85.857506
# 17  2012-09-27   94.898575   97.452858  94.335716   97.331429  87.940750
# 18  2012-09-28   96.964287   97.301430  95.250000   95.300003  86.105347
# 19  2012-10-01   95.879997   96.678574  93.785713   94.198570  85.110161
#
#        Volume
# 0    91973000
# 1    84093800
# 2    97799100
# 3    82416600
# 4   121999500
# 5   125995800
# 6   178058300
# 7   149590000
# 8   150118500
# 9    99507800
# 10   93375800
# 11   81718700
# 12   84142100
# 13  142897300
# 14  159941600
# 15  129697400
# 16  144125800
# 17  148522500
# 18  133777700
# 19  135898700

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
datetime_series = pd.to_datetime(df['Date'])
datetime_index = pd.DatetimeIndex(datetime_series.values)
df = df.set_index(datetime_index)
df = df.sort_values(by='Date')
df = df.drop(columns='Date')

# %%
df.head(5)
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# 2012-09-04  95.108574  96.448570  94.928574  96.424286  87.121140   91973000
# 2012-09-05  96.510002  96.621429  95.657143  95.747147  86.509338   84093800
# 2012-09-06  96.167145  96.898575  95.828575  96.610001  87.288956   97799100
# 2012-09-07  96.864288  97.497147  96.538574  97.205711  87.827171   82416600
# 2012-09-10  97.207146  97.612854  94.585716  94.677139  85.542564  121999500

# %%
# df.loc[:, 'Date'] = pd.to_datetime(df.loc[:, 'Date'], format='%Y/%m/%d')

# %%
X_value = pd.DataFrame(df.iloc[:, :])
y_value = pd.DataFrame(df.iloc[:, 3])

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
# Autocorrelation Check
sm.graphics.tsa.plot_acf(y_value.squeeze(), lags=100)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler(feature_range=(-1, 1))
y_scaler = MinMaxScaler(feature_range=(-1, 1))
X_scaler.fit(X_value)
y_scaler.fit(y_value)
# Out:
# MinMaxScaler(feature_range=(-1, 1))

# %%
X_scale_dataset = X_scaler.fit_transform(X_value)
y_scale_dataset = y_scaler.fit_transform(y_value)

# %%
n_steps_in = 3
n_features = X_value.shape[1]
n_steps_out = 1

# %%
def get_X_y(X_data, y_data):
    X = list()
    y = list()
    yc = list()

    length = len(X_data)
    for i in range(0, length, 1):
        X_value = X_data[i: i + n_steps_in][:, :]
        y_value = y_data[i + n_steps_in: i + (n_steps_in + n_steps_out)][:, 0]
        yc_value = y_data[i: i + n_steps_in][:, :]
        if len(X_value) == 3 and len(y_value) == 1:
            X.append(X_value)
            y.append(y_value)
            yc.append(yc_value)

    return np.array(X), np.array(y), np.array(yc)

# %%
def predict_index(dataset, X_train, n_steps_in, n_steps_out):

    # get the predict data (remove the in_steps days)
    train_predict_index = dataset.iloc[n_steps_in : X_train.shape[0] + n_steps_in + n_steps_out - 1, :].index
    test_predict_index = dataset.iloc[X_train.shape[0] + n_steps_in:, :].index

    return train_predict_index, test_predict_index

# %%
def split_train_test(data):
    train_size = round(len(X) * 0.7)
    data_train = data[0:train_size]
    data_test = data[train_size:]
    return data_train, data_test

# %%
X, y, yc = get_X_y(X_scale_dataset, y_scale_dataset)
X_train, X_test, = split_train_test(X)
y_train, y_test, = split_train_test(y)
yc_train, yc_test, = split_train_test(yc)
index_train, index_test, = predict_index(df, X_train, n_steps_in, n_steps_out)

# %%
print('X shape: ', X.shape)
print('y shape: ', y.shape)
print('X_train shape: ', X_train.shape)
print('y_train shape: ', y_train.shape)
print('y_c_train shape: ', yc_train.shape)
print('X_test shape: ', X_test.shape)
print('y_test shape: ', y_test.shape)
print('y_c_test shape: ', yc_test.shape)
print('index_train shape:', index_train.shape)
print('index_test shape:', index_test.shape)
# Out:
# X shape:  (1255, 3, 6)
# y shape:  (1255, 1)
# X_train shape:  (878, 3, 6)
# y_train shape:  (878, 1)
# y_c_train shape:  (878, 3, 1)
# X_test shape:  (377, 3, 6)
# y_test shape:  (377, 1)
# y_c_test shape:  (377, 3, 1)
# index_train shape: (878,)
# index_test shape: (377,)

# %%
np.save("X_train.npy", X_train)
np.save("y_train.npy", y_train)
np.save("X_test.npy", X_test)
np.save("y_test.npy", y_test)
np.save("yc_train.npy", yc_train)
np.save("yc_test.npy", yc_test)
np.save('index_train.npy', index_train)
np.save('index_test.npy', index_test)

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Bidirectional
from tensorflow.keras.layers import BatchNormalization, Embedding, TimeDistributed, LeakyReLU
from tensorflow.keras.layers import LSTM, GRU
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model

# %%
X_train = np.load("X_train.npy", allow_pickle=True)
y_train = np.load("y_train.npy", allow_pickle=True)
X_test = np.load("X_test.npy", allow_pickle=True)
y_test = np.load("y_test.npy", allow_pickle=True)
yc_train = np.load("yc_train.npy", allow_pickle=True)
yc_test = np.load("yc_test.npy", allow_pickle=True)

# %%
#Parameters
LR = 0.001
BATCH_SIZE = 64
N_EPOCH = 50

input_dim = X_train.shape[1]
feature_size = X_train.shape[2]
output_dim = y_train.shape[1]

# %%
def basic_lstm(input_dim, feature_size):
    model = Sequential()
    model.add(Bidirectional(LSTM(units= 128), input_shape=(input_dim, feature_size)))
    model.add(Dense(64))
    model.add(Dense(units=output_dim))
    model.compile(optimizer=Adam(lr = LR), loss='mse')
    history = model.fit(X_train, y_train, epochs=N_EPOCH, batch_size=BATCH_SIZE, validation_data=(X_test, y_test),
                        verbose=2, shuffle=False)

    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='validation')
    plt.legend()
    plt.show()

    return model

# %%
model = basic_lstm(input_dim, feature_size)
plot_model(model, to_file='lstm_diagram.png', show_shapes=True, show_layer_names=True)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 14/14 - 6s - loss: 0.0817 - val_loss: 0.0141 - 6s/epoch - 463ms/step
# Epoch 2/50
# 14/14 - 1s - loss: 0.0165 - val_loss: 0.0087 - 515ms/epoch - 37ms/step
# Epoch 3/50
# 14/14 - 1s - loss: 0.0120 - val_loss: 0.0045 - 504ms/epoch - 36ms/step
# Epoch 4/50
# 14/14 - 1s - loss: 0.0074 - val_loss: 0.0083 - 523ms/epoch - 37ms/step
# Epoch 5/50
# 14/14 - 1s - loss: 0.0091 - val_loss: 0.0070 - 511ms/epoch - 37ms/step
# Epoch 6/50
# 14/14 - 1s - loss: 0.0156 - val_loss: 0.0262 - 585ms/epoch - 42ms/step
# Epoch 7/50
# 14/14 - 1s - loss: 0.0320 - val_loss: 0.0245 - 580ms/epoch - 41ms/step
# Epoch 8/50
# 14/14 - 1s - loss: 0.0362 - val_loss: 0.0304 - 510ms/epoch - 36ms/step
# Epoch 9/50
# 14/14 - 0s - loss: 0.0586 - val_loss: 0.0051 - 485ms/epoch - 35ms/step
# Epoch 10/50
# 14/14 - 0s - loss: 0.0087 - val_loss: 0.0025 - 256ms/epoch - 18ms/step
# Epoch 11/50
# 14/14 - 0s - loss: 0.0052 - val_loss: 0.0029 - 270ms/epoch - 19ms/step
# Epoch 12/50
# 14/14 - 0s - loss: 0.0028 - val_loss: 0.0014 - 307ms/epoch - 22ms/step
# Epoch 13/50
# 14/14 - 0s - loss: 0.0026 - val_loss: 0.0023 - 259ms/epoch - 19ms/step
# Epoch 14/50
# 14/14 - 0s - loss: 0.0018 - val_loss: 0.0013 - 262ms/epoch - 19ms/step
# Epoch 15/50
# 14/14 - 0s - loss: 0.0019 - val_loss: 0.0018 - 281ms/epoch - 20ms/step
# Epoch 16/50
# 14/14 - 0s - loss: 0.0016 - val_loss: 0.0013 - 288ms/epoch - 21ms/step
# Epoch 17/50
# 14/14 - 0s - loss: 0.0017 - val_loss: 0.0016 - 266ms/epoch - 19ms/step
# Epoch 18/50
# 14/14 - 0s - loss: 0.0015 - val_loss: 0.0013 - 289ms/epoch - 21ms/step
# Epoch 19/50
# 14/14 - 0s - loss: 0.0017 - val_loss: 0.0015 - 287ms/epoch - 21ms/step
# Epoch 20/50
# 14/14 - 0s - loss: 0.0015 - val_loss: 0.0014 - 263ms/epoch - 19ms/step
# Epoch 21/50
# 14/14 - 0s - loss: 0.0018 - val_loss: 0.0015 - 293ms/epoch - 21ms/step
# Epoch 22/50
# 14/14 - 0s - loss: 0.0016 - val_loss: 0.0015 - 294ms/epoch - 21ms/step
# Epoch 23/50
# 14/14 - 0s - loss: 0.0020 - val_loss: 0.0017 - 277ms/epoch - 20ms/step
# Epoch 24/50
# 14/14 - 0s - loss: 0.0019 - val_loss: 0.0021 - 297ms/epoch - 21ms/step
# Epoch 25/50
# 14/14 - 0s - loss: 0.0027 - val_loss: 0.0023 - 315ms/epoch - 22ms/step
# Epoch 26/50
# 14/14 - 0s - loss: 0.0028 - val_loss: 0.0035 - 288ms/epoch - 21ms/step
# Epoch 27/50
# 14/14 - 0s - loss: 0.0048 - val_loss: 0.0041 - 261ms/epoch - 19ms/step
# Epoch 28/50
# 14/14 - 0s - loss: 0.0055 - val_loss: 0.0068 - 280ms/epoch - 20ms/step
# Epoch 29/50
# 14/14 - 0s - loss: 0.0105 - val_loss: 0.0082 - 285ms/epoch - 20ms/step
# Epoch 30/50
# 14/14 - 0s - loss: 0.0108 - val_loss: 0.0112 - 295ms/epoch - 21ms/step
# Epoch 31/50
# 14/14 - 0s - loss: 0.0202 - val_loss: 0.0104 - 288ms/epoch - 21ms/step
# Epoch 32/50
# 14/14 - 0s - loss: 0.0132 - val_loss: 0.0090 - 257ms/epoch - 18ms/step
# Epoch 33/50
# 14/14 - 0s - loss: 0.0207 - val_loss: 0.0077 - 305ms/epoch - 22ms/step
# Epoch 34/50
# 14/14 - 0s - loss: 0.0088 - val_loss: 0.0039 - 258ms/epoch - 18ms/step
# Epoch 35/50
# 14/14 - 0s - loss: 0.0111 - val_loss: 0.0057 - 269ms/epoch - 19ms/step
# Epoch 36/50
# 14/14 - 0s - loss: 0.0061 - val_loss: 0.0019 - 304ms/epoch - 22ms/step
# Epoch 37/50
# 14/14 - 0s - loss: 0.0073 - val_loss: 0.0020 - 301ms/epoch - 22ms/step
# Epoch 38/50
# 14/14 - 0s - loss: 0.0040 - val_loss: 0.0023 - 261ms/epoch - 19ms/step
# Epoch 39/50
# 14/14 - 0s - loss: 0.0032 - val_loss: 0.0016 - 303ms/epoch - 22ms/step
# Epoch 40/50
# 14/14 - 0s - loss: 0.0019 - val_loss: 0.0022 - 269ms/epoch - 19ms/step
# Epoch 41/50
# 14/14 - 0s - loss: 0.0015 - val_loss: 0.0013 - 258ms/epoch - 18ms/step
# Epoch 42/50
# 14/14 - 0s - loss: 0.0015 - val_loss: 0.0014 - 269ms/epoch - 19ms/step
# Epoch 43/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 294ms/epoch - 21ms/step
# Epoch 44/50
# 14/14 - 0s - loss: 0.0015 - val_loss: 0.0013 - 317ms/epoch - 23ms/step
# Epoch 45/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 486ms/epoch - 35ms/step
# Epoch 46/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 493ms/epoch - 35ms/step
# Epoch 47/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 496ms/epoch - 35ms/step
# Epoch 48/50
# 14/14 - 1s - loss: 0.0014 - val_loss: 0.0012 - 501ms/epoch - 36ms/step
# Epoch 49/50
# 14/14 - 1s - loss: 0.0014 - val_loss: 0.0013 - 505ms/epoch - 36ms/step
# Epoch 50/50
# 14/14 - 0s - loss: 0.0015 - val_loss: 0.0012 - 467ms/epoch - 33ms/step

# %%
from math import sqrt

# %%
model = basic_lstm(input_dim, feature_size)
model.save('LSTM_3to1.h5')
print(model.summary())

yhat = model.predict(X_test, verbose=0)
#print(yhat)

rmse = sqrt(mean_squared_error(y_test, yhat))
print(rmse)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 14/14 - 6s - loss: 0.0564 - val_loss: 0.0068 - 6s/epoch - 397ms/step
# Epoch 2/50
# 14/14 - 0s - loss: 0.0041 - val_loss: 0.0044 - 283ms/epoch - 20ms/step
# Epoch 3/50
# 14/14 - 0s - loss: 0.0039 - val_loss: 0.0067 - 257ms/epoch - 18ms/step
# Epoch 4/50
# 14/14 - 0s - loss: 0.0039 - val_loss: 0.0028 - 265ms/epoch - 19ms/step
# Epoch 5/50
# 14/14 - 0s - loss: 0.0144 - val_loss: 0.0268 - 298ms/epoch - 21ms/step
# Epoch 6/50
# 14/14 - 0s - loss: 0.0257 - val_loss: 0.0344 - 276ms/epoch - 20ms/step
# Epoch 7/50
# 14/14 - 0s - loss: 0.0538 - val_loss: 0.0939 - 291ms/epoch - 21ms/step
# Epoch 8/50
# 14/14 - 0s - loss: 0.1048 - val_loss: 0.0137 - 254ms/epoch - 18ms/step
# Epoch 9/50
# 14/14 - 0s - loss: 0.0274 - val_loss: 0.0135 - 287ms/epoch - 20ms/step
# Epoch 10/50
# 14/14 - 0s - loss: 0.0289 - val_loss: 0.0069 - 283ms/epoch - 20ms/step
# Epoch 11/50
# 14/14 - 0s - loss: 0.0113 - val_loss: 0.0047 - 263ms/epoch - 19ms/step
# Epoch 12/50
# 14/14 - 0s - loss: 0.0072 - val_loss: 0.0020 - 287ms/epoch - 20ms/step
# Epoch 13/50
# 14/14 - 0s - loss: 0.0027 - val_loss: 0.0016 - 267ms/epoch - 19ms/step
# Epoch 14/50
# 14/14 - 0s - loss: 0.0020 - val_loss: 0.0019 - 287ms/epoch - 20ms/step
# Epoch 15/50
# 14/14 - 0s - loss: 0.0016 - val_loss: 0.0014 - 316ms/epoch - 23ms/step
# Epoch 16/50
# 14/14 - 0s - loss: 0.0016 - val_loss: 0.0016 - 482ms/epoch - 34ms/step
# Epoch 17/50
# 14/14 - 1s - loss: 0.0015 - val_loss: 0.0015 - 504ms/epoch - 36ms/step
# Epoch 18/50
# 14/14 - 1s - loss: 0.0015 - val_loss: 0.0015 - 504ms/epoch - 36ms/step
# Epoch 19/50
# 14/14 - 0s - loss: 0.0015 - val_loss: 0.0014 - 493ms/epoch - 35ms/step
# Epoch 20/50
# 14/14 - 1s - loss: 0.0015 - val_loss: 0.0014 - 584ms/epoch - 42ms/step
# Epoch 21/50
# 14/14 - 0s - loss: 0.0015 - val_loss: 0.0014 - 494ms/epoch - 35ms/step
# Epoch 22/50
# 14/14 - 0s - loss: 0.0015 - val_loss: 0.0014 - 484ms/epoch - 35ms/step
# Epoch 23/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 469ms/epoch - 34ms/step
# Epoch 24/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 461ms/epoch - 33ms/step
# Epoch 25/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 284ms/epoch - 20ms/step
# Epoch 26/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 274ms/epoch - 20ms/step
# Epoch 27/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 292ms/epoch - 21ms/step
# Epoch 28/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 260ms/epoch - 19ms/step
# Epoch 29/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 258ms/epoch - 18ms/step
# Epoch 30/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 256ms/epoch - 18ms/step
# Epoch 31/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 294ms/epoch - 21ms/step
# Epoch 32/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 288ms/epoch - 21ms/step
# Epoch 33/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 266ms/epoch - 19ms/step
# Epoch 34/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 289ms/epoch - 21ms/step
# Epoch 35/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 313ms/epoch - 22ms/step
# Epoch 36/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 290ms/epoch - 21ms/step
# Epoch 37/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0014 - 290ms/epoch - 21ms/step
# Epoch 38/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0014 - 262ms/epoch - 19ms/step
# Epoch 39/50
# 14/14 - 0s - loss: 0.0013 - val_loss: 0.0014 - 284ms/epoch - 20ms/step
# Epoch 40/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0014 - 276ms/epoch - 20ms/step
# Epoch 41/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 303ms/epoch - 22ms/step
# Epoch 42/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0016 - 282ms/epoch - 20ms/step
# Epoch 43/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0013 - 270ms/epoch - 19ms/step
# Epoch 44/50
# 14/14 - 0s - loss: 0.0014 - val_loss: 0.0021 - 290ms/epoch - 21ms/step
# Epoch 45/50
# 14/14 - 0s - loss: 0.0018 - val_loss: 0.0014 - 275ms/epoch - 20ms/step
# Epoch 46/50
# 14/14 - 0s - loss: 0.0020 - val_loss: 0.0037 - 324ms/epoch - 23ms/step
# Epoch 47/50
# 14/14 - 0s - loss: 0.0033 - val_loss: 0.0028 - 270ms/epoch - 19ms/step
# Epoch 48/50
# 14/14 - 0s - loss: 0.0040 - val_loss: 0.0071 - 287ms/epoch - 20ms/step
# Epoch 49/50
# 14/14 - 0s - loss: 0.0076 - val_loss: 0.0067 - 294ms/epoch - 21ms/step
# Epoch 50/50
# 14/14 - 0s - loss: 0.0088 - val_loss: 0.0100 - 284ms/epoch - 20ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_3 (Bidirecti  (None, 256)               138240
#  onal)
#
#  dense_6 (Dense)             (None, 64)                16448
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 154753 (604.50 KB)
# Trainable params: 154753 (604.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# 0.09999655125631035

# %%
def plot_traindataset_result(X_train, y_train):


    train_yhat = model.predict(X_train, verbose=0)

    X_scaler = load(open('X_scaler.pkl', 'rb'))
    y_scaler = load(open('y_scaler.pkl', 'rb'))
    train_predict_index = np.load("index_train.npy", allow_pickle=True)

    rescaled_real_y = y_scaler.inverse_transform(y_train)
    rescaled_predicted_y = y_scaler.inverse_transform(train_yhat)

    predict_result = pd.DataFrame()
    for i in range(rescaled_predicted_y.shape[0]):
        y_predict = pd.DataFrame(rescaled_predicted_y[i], columns=["predicted_price"],
                                 index=train_predict_index[i:i + output_dim])
        predict_result = pd.concat([predict_result, y_predict], axis=1, sort=False)
    #
    real_price = pd.DataFrame()
    for i in range(rescaled_real_y.shape[0]):
        y_train = pd.DataFrame(rescaled_real_y[i], columns=["real_price"],
                               index=train_predict_index[i:i + output_dim])
        real_price = pd.concat([real_price, y_train], axis=1, sort=False)

    predict_result['predicted_mean'] = predict_result.mean(axis=1)
    real_price['real_mean'] = real_price.mean(axis=1)
    #
    # Plot the predicted result
    plt.figure(figsize=(16, 8))
    plt.plot(real_price["real_mean"])
    plt.plot(predict_result["predicted_mean"], color='r')
    plt.xlabel("Date")
    plt.ylabel("Stock price")
    plt.legend(("Real price", "Predicted price"), loc="upper left", fontsize=16)
    plt.title("The result of Training", fontsize=20)
    plt.show()

    # Calculate RMSE
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]
    RMSE = np.sqrt(mean_squared_error(predicted, real))
    #print('-- Train RMSE -- ', RMSE)

    return RMSE

# %%
# %% --------------------------------------- Plot the TEST result  -----------------------------------------------------------------
def plot_testdataset_result(X_test, y_test):

    test_yhat = model.predict(X_test, verbose=0)
    y_scaler = load(open('y_scaler.pkl', 'rb'))
    test_predict_index = np.load("index_test.npy", allow_pickle=True)

    rescaled_real_y = y_scaler.inverse_transform(y_test)
    rescaled_predicted_y = y_scaler.inverse_transform(test_yhat)

    predict_result = pd.DataFrame()
    for i in range(rescaled_predicted_y.shape[0]):
        y_predict = pd.DataFrame(rescaled_predicted_y[i], columns=["predicted_price"],
                                 index=test_predict_index[i:i + output_dim])
        predict_result = pd.concat([predict_result, y_predict], axis=1, sort=False)

    real_price = pd.DataFrame()
    for i in range(rescaled_real_y.shape[0]):
        y_train = pd.DataFrame(rescaled_real_y[i], columns=["real_price"],
                               index=test_predict_index[i:i + output_dim])
        real_price = pd.concat([real_price, y_train], axis=1, sort=False)

    predict_result['predicted_mean'] = predict_result.mean(axis=1)
    real_price['real_mean'] = real_price.mean(axis=1)

    Input_Before = '2020-01-01'
    predict_result = predict_result.loc[predict_result.index < Input_Before]
    real_price = real_price.loc[real_price.index < Input_Before]

    print(predict_result.tail(10))

    # Plot the predicted result
    plt.figure(figsize=(16, 8))
    plt.plot(real_price["real_mean"])
    plt.plot(predict_result["predicted_mean"], color='r')
    plt.xlabel("Date")
    plt.ylabel("Stock price")
    plt.legend(("Real price", "Predicted price"), loc="upper left", fontsize=16)
    plt.title("The result of Testing", fontsize=20)
    plt.show()

    # Calculate RMSE
    predicted = predict_result["predicted_mean"]
    real = real_price["real_mean"]
    RMSE = np.sqrt(mean_squared_error(predicted, real))
    #print('-- Test RMSE -- ', RMSE)

    return RMSE

# %%
from pickle import dump, load

# %%
dump(X_scaler, open('X_scaler.pkl', 'wb'))
dump(y_scaler, open('y_scaler.pkl', 'wb'))

# %%
train_RMSE = plot_traindataset_result(X_train, y_train)
print("----- Train_RMSE_LSTM -----", train_RMSE)

test_RMSE = plot_testdataset_result(X_test, y_test)
print("----- Test_RMSE_LSTM -----", test_RMSE)
# Out:
# ----- Train_RMSE_LSTM ----- 2.1618095754940794
#             predicted_price  predicted_price  predicted_price  \
# 2017-08-21              NaN              NaN              NaN
# 2017-08-22              NaN              NaN              NaN
# 2017-08-23              NaN              NaN              NaN
# 2017-08-24              NaN              NaN              NaN
# 2017-08-25              NaN              NaN              NaN
# 2017-08-28              NaN              NaN              NaN
# 2017-08-29              NaN              NaN              NaN
# 2017-08-30              NaN              NaN              NaN
# 2017-08-31              NaN              NaN              NaN
# 2017-09-01              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2017-08-21              NaN              NaN              NaN
# 2017-08-22              NaN              NaN              NaN
# 2017-08-23              NaN              NaN              NaN
# 2017-08-24              NaN              NaN              NaN
# 2017-08-25              NaN              NaN              NaN
# 2017-08-28              NaN              NaN              NaN
# 2017-08-29              NaN              NaN              NaN
# 2017-08-30              NaN              NaN              NaN
# 2017-08-31              NaN              NaN              NaN
# 2017-09-01              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2017-08-21              NaN              NaN              NaN
# 2017-08-22              NaN              NaN              NaN
# 2017-08-23              NaN              NaN              NaN
# 2017-08-24              NaN              NaN              NaN
# 2017-08-25              NaN              NaN              NaN
# 2017-08-28              NaN              NaN              NaN
# 2017-08-29              NaN              NaN              NaN
# 2017-08-30              NaN              NaN              NaN
# 2017-08-31              NaN              NaN              NaN
# 2017-09-01              NaN              NaN              NaN
#
#             predicted_price  ...  predicted_price  predicted_price  \
# 2017-08-21              NaN  ...              NaN              NaN
# 2017-08-22              NaN  ...       159.600723              NaN
# 2017-08-23              NaN  ...              NaN       159.809082
# 2017-08-24              NaN  ...              NaN              NaN
# 2017-08-25              NaN  ...              NaN              NaN
# 2017-08-28              NaN  ...              NaN              NaN
# 2017-08-29              NaN  ...              NaN              NaN
# 2017-08-30              NaN  ...              NaN              NaN
# 2017-08-31              NaN  ...              NaN              NaN
# 2017-09-01              NaN  ...              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2017-08-21              NaN              NaN              NaN
# 2017-08-22              NaN              NaN              NaN
# 2017-08-23              NaN              NaN              NaN
# 2017-08-24       160.439911              NaN              NaN
# 2017-08-25              NaN       161.242767              NaN
# 2017-08-28              NaN              NaN       161.431229
# 2017-08-29              NaN              NaN              NaN
# 2017-08-30              NaN              NaN              NaN
# 2017-08-31              NaN              NaN              NaN
# 2017-09-01              NaN              NaN              NaN
#
#             predicted_price  predicted_price  predicted_price  \
# 2017-08-21              NaN              NaN              NaN
# 2017-08-22              NaN              NaN              NaN
# 2017-08-23              NaN              NaN              NaN
# 2017-08-24              NaN              NaN              NaN
# 2017-08-25              NaN              NaN              NaN
# 2017-08-28              NaN              NaN              NaN
# 2017-08-29        161.89238              NaN              NaN
# 2017-08-30              NaN       162.510483              NaN
# 2017-08-31              NaN              NaN       163.642685
# 2017-09-01              NaN              NaN              NaN
#
#             predicted_price  predicted_mean
# 2017-08-21              NaN      160.960541
# 2017-08-22              NaN      159.600723
# 2017-08-23              NaN      159.809082
# 2017-08-24              NaN      160.439911
# 2017-08-25              NaN      161.242767
# 2017-08-28              NaN      161.431229
# 2017-08-29              NaN      161.892380
# 2017-08-30              NaN      162.510483
# 2017-08-31              NaN      163.642685
# 2017-09-01       164.565674      164.565674
#
# [10 rows x 378 columns]
# ----- Test_RMSE_LSTM ----- 2.0852390856096674

# %%
df['7_d_avg'] = df['Close'].rolling(window=7).mean()
df['10_d_avg'] = df['Close'].rolling(window=10).mean()
df['50_d_avg'] = df['Close'].rolling(window=50).mean()

# %%
# df = df.drop('200_d_avg', axis=1)
df.head(15)
# Out:
#                   Open        High        Low       Close  Adj Close  \
# 2012-09-04   95.108574   96.448570  94.928574   96.424286  87.121140
# 2012-09-05   96.510002   96.621429  95.657143   95.747147  86.509338
# 2012-09-06   96.167145   96.898575  95.828575   96.610001  87.288956
# 2012-09-07   96.864288   97.497147  96.538574   97.205711  87.827171
# 2012-09-10   97.207146   97.612854  94.585716   94.677139  85.542564
# 2012-09-11   95.015717   95.728569  93.785713   94.370003  85.265068
# 2012-09-12   95.264282   95.699997  93.714287   95.684288  86.452538
# 2012-09-13   96.767143   97.928574  96.395714   97.568573  88.155037
# 2012-09-14   98.565712   99.568573  98.269997   98.754288  89.226341
# 2012-09-17   99.907143   99.971428  99.230003   99.968575  90.323479
# 2012-09-18   99.982857  100.332855  99.488571  100.272858  90.598404
# 2012-09-19  100.037140  100.570000  99.938568  100.300003  90.622932
# 2012-09-20   99.879997  100.008568  99.088570   99.814285  90.184090
# 2012-09-21  100.344284  100.724289  99.908569  100.012856  90.363457
# 2012-09-24   98.122856   99.302856  97.571426   98.684288  89.163078
#
#                Volume    7_d_avg   10_d_avg  50_d_avg
# 2012-09-04   91973000        NaN        NaN       NaN
# 2012-09-05   84093800        NaN        NaN       NaN
# 2012-09-06   97799100        NaN        NaN       NaN
# 2012-09-07   82416600        NaN        NaN       NaN
# 2012-09-10  121999500        NaN        NaN       NaN
# 2012-09-11  125995800        NaN        NaN       NaN
# 2012-09-12  178058300  95.816939        NaN       NaN
# 2012-09-13  149590000  95.980409        NaN       NaN
# 2012-09-14  150118500  96.410000        NaN       NaN
# 2012-09-17   99507800  96.889797  96.701001       NaN
# 2012-09-18   93375800  97.327961  97.085858       NaN
# 2012-09-19   81718700  98.131227  97.541144       NaN
# 2012-09-20   84142100  98.908981  97.861572       NaN
# 2012-09-21  142897300  99.527348  98.142287       NaN
# 2012-09-24  159941600  99.686736  98.543002       NaN

# %%
df['returns'] = ((df['Adj Close'] / df['Adj Close'].shift(1)) - 1) * 100

# %%
df.head(50)
# Out:
#                   Open        High        Low       Close  Adj Close  \
# 2012-09-04   95.108574   96.448570  94.928574   96.424286  87.121140
# 2012-09-05   96.510002   96.621429  95.657143   95.747147  86.509338
# 2012-09-06   96.167145   96.898575  95.828575   96.610001  87.288956
# 2012-09-07   96.864288   97.497147  96.538574   97.205711  87.827171
# 2012-09-10   97.207146   97.612854  94.585716   94.677139  85.542564
# 2012-09-11   95.015717   95.728569  93.785713   94.370003  85.265068
# 2012-09-12   95.264282   95.699997  93.714287   95.684288  86.452538
# 2012-09-13   96.767143   97.928574  96.395714   97.568573  88.155037
# 2012-09-14   98.565712   99.568573  98.269997   98.754288  89.226341
# 2012-09-17   99.907143   99.971428  99.230003   99.968575  90.323479
# 2012-09-18   99.982857  100.332855  99.488571  100.272858  90.598404
# 2012-09-19  100.037140  100.570000  99.938568  100.300003  90.622932
# 2012-09-20   99.879997  100.008568  99.088570   99.814285  90.184090
# 2012-09-21  100.344284  100.724289  99.908569  100.012856  90.363457
# 2012-09-24   98.122856   99.302856  97.571426   98.684288  89.163078
# 2012-09-25   98.322861   98.968575  96.142860   96.220001  86.936554
# 2012-09-26   95.534286   96.098572  94.457146   95.025711  85.857506
# 2012-09-27   94.898575   97.452858  94.335716   97.331429  87.940750
# 2012-09-28   96.964287   97.301430  95.250000   95.300003  86.105347
# 2012-10-01   95.879997   96.678574  93.785713   94.198570  85.110161
# 2012-10-02   94.544289   95.192856  92.949997   94.472855  85.358002
# 2012-10-03   94.980003   95.980003  94.661430   95.921425  86.666817
# 2012-10-04   95.892860   96.321426  95.078575   95.257141  86.066612
# 2012-10-05   95.028572   95.142860  93.040001   93.227142  84.232460
# 2012-10-08   92.411430   92.508568  90.872856   91.167145  82.371223
# 2012-10-09   91.235718   91.498573  89.078575   90.835716  82.071747
# 2012-10-10   91.391426   92.139999  91.000000   91.558571  82.724876
# 2012-10-11   92.357140   92.457146  89.728569   89.728569  81.071426
# 2012-10-12   89.937141   90.768570  89.328575   89.958572  81.279243
# 2012-10-15   90.335716   90.732857  89.121429   90.680000  81.931084
# 2012-10-16   90.767143   92.900002  90.142860   92.827141  83.871056
# 2012-10-17   92.695717   93.255714  92.000000   92.087143  83.202446
# 2012-10-18   91.370003   91.722855  90.000000   90.377144  81.657455
# 2012-10-19   90.150002   90.252853  87.088570   87.120003  78.714554
# 2012-10-22   87.488571   90.768570  87.251427   90.575714  81.836838
# 2012-10-23   90.142860   90.557144  87.385712   87.622856  79.168869
# 2012-10-24   88.777145   89.507141  87.234283   88.118568  79.616783
# 2012-10-25   88.571426   88.857140  86.507141   87.077141  78.675812
# 2012-10-26   87.061432   87.714287  84.428574   86.285713  77.960747
# 2012-10-31   84.982857   85.994286  83.957146   85.045715  76.840401
# 2012-11-01   85.459999   86.142860  84.881432   85.220001  76.997864
# 2012-11-02   85.127144   85.278572  82.107140   82.400002  74.449928
# 2012-11-05   83.360001   83.967140  82.514282   83.517143  75.459290
# 2012-11-06   84.318573   84.391426  82.870003   83.264282  75.230835
# 2012-11-07   81.977142   82.077141  79.392860   79.714287  72.352310
# 2012-11-08   80.089996   80.318573  76.470001   76.821426  69.726601
# 2012-11-09   77.202858   79.268570  76.245712   78.151428  70.933784
# 2012-11-12   79.164284   79.214287  76.949997   77.547142  70.385323
# 2012-11-13   76.987144   78.639999  76.622856   77.557144  70.394394
# 2012-11-14   77.928574   78.207146  76.597145   76.697144  69.613815
#
#                Volume    7_d_avg   10_d_avg   50_d_avg   returns
# 2012-09-04   91973000        NaN        NaN        NaN       NaN
# 2012-09-05   84093800        NaN        NaN        NaN -0.702243
# 2012-09-06   97799100        NaN        NaN        NaN  0.901195
# 2012-09-07   82416600        NaN        NaN        NaN  0.616590
# 2012-09-10  121999500        NaN        NaN        NaN -2.601253
# 2012-09-11  125995800        NaN        NaN        NaN -0.324395
# 2012-09-12  178058300  95.816939        NaN        NaN  1.392681
# 2012-09-13  149590000  95.980409        NaN        NaN  1.969287
# 2012-09-14  150118500  96.410000        NaN        NaN  1.215250
# 2012-09-17   99507800  96.889797  96.701001        NaN  1.229612
# 2012-09-18   93375800  97.327961  97.085858        NaN  0.304378
# 2012-09-19   81718700  98.131227  97.541144        NaN  0.027073
# 2012-09-20   84142100  98.908981  97.861572        NaN -0.484250
# 2012-09-21  142897300  99.527348  98.142287        NaN  0.198890
# 2012-09-24  159941600  99.686736  98.543002        NaN -1.328390
# 2012-09-25  129697400  99.324695  98.728002        NaN -2.497137
# 2012-09-26  144125800  98.618572  98.662144        NaN -1.241190
# 2012-09-27  148522500  98.198368  98.638429        NaN  2.426397
# 2012-09-28  133777700  97.484082  98.293001        NaN -2.087090
# 2012-10-01  135898700  96.681837  97.716000        NaN -1.155777
# 2012-10-02  156998100  95.890408  97.136000        NaN  0.291200
# 2012-10-03  106070300  95.495713  96.698142        NaN  1.533324
# 2012-10-04   92681400  95.358162  96.242428        NaN -0.692543
# 2012-10-05  148501500  95.101224  95.563857        NaN -2.131084
# 2012-10-08  159498500  94.220612  94.812142        NaN -2.209643
# 2012-10-09  209649300  93.582856  94.273714        NaN -0.363569
# 2012-10-10  127589000  93.205714  93.927000        NaN  0.795802
# 2012-10-11  136520300  92.527958  93.166714        NaN -1.998734
# 2012-10-12  115003700  91.676122  92.632571        NaN  0.256338
# 2012-10-15  108125500  91.022245  92.280714        NaN  0.801977
# 2012-10-16  137442900  90.965102  92.116142        NaN  2.367810
# 2012-10-17   97259400  91.096530  91.732714        NaN -0.797188
# 2012-10-18  119156100  91.031020  91.244714        NaN -1.856906
# 2012-10-19  186021500  90.396939  90.634000        NaN -3.603959
# 2012-10-22  136682700  90.517960  90.574857        NaN  3.966590
# 2012-10-23  176786400  90.184286  90.253571        NaN -3.260108
# 2012-10-24  139631800  89.818367  89.909571        NaN  0.565770
# 2012-10-25  164081400  88.996938  89.644428        NaN -1.181875
# 2012-10-26  254608200  88.168163  89.277142        NaN -0.908875
# 2012-10-31  127500800  87.406530  88.713714        NaN -1.437064
# 2012-11-01   90324500  87.135101  87.953000        NaN  0.204922
# 2012-11-02  149843400  85.967142  86.984286        NaN -3.309100
# 2012-11-05  132283900  85.380612  86.298286        NaN  1.355760
# 2012-11-06   93729300  84.687142  85.912714        NaN -0.302753
# 2012-11-07  198412200  83.635306  84.826571        NaN -3.826257
# 2012-11-08  264036500  82.283265  83.746428        NaN -3.629060
# 2012-11-09  232478400  81.298367  82.749714        NaN  1.731309
# 2012-11-12  128950500  80.202244  81.796714        NaN -0.773201
# 2012-11-13  133237300  79.510407  80.923857        NaN  0.012888
# 2012-11-14  119292600  78.536122  80.089000  91.100086 -1.108865
